# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
os.chdir('/content/gdrive/My Drive/Colab Notebooks/ssd')
os.listdir()
# Out:
# ['data',
#  'train',
#  'evaluate',
#  'tools',
#  'detect',
#  'symbol',
#  'model',
#  'dataset',
#  'config',
#  'benchmark_score.py',
#  'deploy.py',
#  'init.sh',
#  'quantization.py',
#  'README.md',
#  'train.py',
#  '__init__.py',
#  'train.log',
#  'evaluate0101.py',
#  'test',
#  'test_video',
#  'demo.py',
#  'evaluate.py']

# %%
# !nvcc --version
# !pip install mxnet-cu100
import mxnet as mx
a = mx.nd.ones((2, 3), mx.gpu())
b = a * 2 + 1
b.asnumpy()
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2018 NVIDIA Corporation
# Built on Sat_Aug_25_21:08:01_CDT_2018
# Cuda compilation tools, release 10.0, V10.0.130
# ...
# array([[3., 3., 3.],
#        [3., 3., 3.]], dtype=float32)

# %% [markdown]
# **Evaluation**

# %%
import argparse

# !python evaluate.py --gpus 0 --epoch 200 --data-shape 300 --num-class 13 --class-names 'ambulance, taxi, firetruck, garbage truck, minibus, minivan, motor scooter, mountain bike, moving van, police car, tow truck, trailer truck, compact car'

# %% [markdown]
# **Video**

# %%
# !python demo.py --gpu 0 --camera --epoch 200 --network vgg16_reduced --data-shape 300 --class-names 'ambulance, taxi, firetruck, garbage truck, minibus, minivan, motor scooter, mountain bike, moving van, police car, tow truck, trailer truck, compact car'
#ssd_vgg16_reduced_300-0200.params
# Out:
# [ WARN:0] global /io/opencv/modules/videoio/src/cap_v4l.cpp (802) open VIDEOIO ERROR: V4L: can't open camera by index 0
# 2020-01-14 02:47:16,091 Detection threshold is 0.5
# read success
# Traceback (most recent call last):
#   File "demo.py", line 280, in <module>
#     sys.exit(main())
#   File "demo.py", line 274, in main
#     run_camera(args, ctx)
#   File "demo.py", line 190, in run_camera
#     cv2.resize(frame, (300, 300))
# cv2.error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %% [markdown]
# **Demo (Picture)**

# %%
# %matplotlib inline
# !python demo.py --gpu 0 --prefix './model/ssd_vgg16_reduced_300' --epoch 200 --network vgg16_reduced --data-shape 300 --class-names 'ambulance, taxi, firetruck, garbage truck, minibus, minivan, motor scooter, mountain bike, moving van, police car, tow truck, trailer truck, compact car'
#ssd_vgg16_reduced_300-0200.params
# Out:
# [ WARN:0] global /io/opencv/modules/videoio/src/cap_v4l.cpp (802) open VIDEOIO ERROR: V4L: can't open camera by index 0
# [06:40:02] src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# 2020-01-07 06:42:02,470 Detection time for 306 images: 119.8918 sec
# 2020-01-07 06:42:08,339 5 positive detections
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>
# ...

# %% [markdown]
# **Training**

# %%
import argparse
import mxnet as mx
import os

# !python train.py --gpus 0 --num-class 13 --num-example 3437 --class-names 'ambulance, taxi, firetruck, garbage truck, minibus, minivan, motor scooter, mountain bike, moving van, police car, tow truck, trailer truck, compact car'
# Out:
# [13:50:51] src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /content/gdrive/My Drive/Colab Notebooks/ssd/data/train.rec, use 1 threads for decoding..
# [13:50:57] src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /content/gdrive/My Drive/Colab Notebooks/ssd/data/train.rec, label padding width: 350
# [13:51:00] src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /content/gdrive/My Drive/Colab Notebooks/ssd/data/val.rec, use 1 threads for decoding..
# [13:51:01] src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /content/gdrive/My Drive/Colab Notebooks/ssd/data/val.rec, label padding width: 350
# INFO:root:Start training with (gpu(0)) from pretrained model /content/gdrive/My Drive/Colab Notebooks/ssd/model/vgg16_reduced
# [13:51:04] src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v0.8.0. Attempting to upgrade...
# [13:51:04] src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# ...

# %%
''' Training (old)'''
#import argparse
#import mxnet as mx
#import os

#!python train.py --gpus 0 --num-class 13 --num-example 3437 --class-names 'ambulance, taxi, firetruck, garbage truck, minibus, minivan, motor scooter, mountain bike, moving van, police car, tow truck, trailer truck, compact car'
# Out:
# [08:42:55] src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /content/gdrive/My Drive/Colab Notebooks/ssd/data/train.rec, use 1 threads for decoding..
# [08:42:56] src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /content/gdrive/My Drive/Colab Notebooks/ssd/data/train.rec, label padding width: 350
# [08:42:58] src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /content/gdrive/My Drive/Colab Notebooks/ssd/data/val.rec, use 1 threads for decoding..
# [08:42:58] src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /content/gdrive/My Drive/Colab Notebooks/ssd/data/val.rec, label padding width: 350
# INFO:root:Start training with (gpu(0)) from pretrained model /content/gdrive/My Drive/Colab Notebooks/ssd/model/vgg16_reduced
# [08:43:00] src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v0.8.0. Attempting to upgrade...
# [08:43:00] src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# ...
